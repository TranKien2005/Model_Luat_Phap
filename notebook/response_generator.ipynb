# %% [markdown]
# # Legal Benchmark - Response Generator

# %%
# !pip install transformers torch accelerate -q

# %%
import sys
sys.path.append('./evaluator')

from responseGenerator import run_all_benchmark_models
run_all_benchmark_models()
